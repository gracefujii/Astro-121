# %% [markdown]
# # Lab 2

# %%
import ugradio
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
def PS(x):
    """Takes in a complex array and outputs a plot of frequency versus power spectrum."""

    Vsamp = 62.5/8
    N = 16000

    time = np.linspace(-N/(2*Vsamp),(N/2-1)/Vsamp,N)
    
    f,fx = ugradio.dft.dft(x[:N],t=time, vsamp=Vsamp)
    P = np.abs(fx)**2
    plt.plot(f,P)
    plt.xlabel("Frequency")
    plt.ylabel("Power")
    plt.show()

# %%
# x = ugradio.pico.capture_data('50mV', divisor=15, dual_mode=True, nsamples=4000)
# np.savetxt('data_2.6.2', x)

# captured 02/15/2019 18:56 PST

# %%
x = np.loadtxt('data_2.6.2')
plt.hist(x, bins=20)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# x = ugradio.pico.capture_data('50mV', divisor=15, dual_mode=True, nsamples=4000)
# np.savetxt('data_2.6.2_test', x)

# %%
x = np.loadtxt('data_2.6.2_test')
a = x[:len(x)/2]
b = x[len(x)/2:]
c = a + b * 1j
PS(c)
# Out:
# <img src="data:image/png;base64,...">

# %%
# np.savez()

# %%
x = ugradio.pico.capture_data('50mV', divisor=8, dual_mode=True)
np.savetxt('data_2.6.2_upper', x)

# first lo set to 1231 MHz -- upper baseband

# %%
x = np.loadtxt('data_2.6.2_upper')
a = x[:len(x)/2]
b = x[len(x)/2:]
c = a + b * 1j
PS(c)
# Out:
# <img src="data:image/png;base64,...">

# %%
x = ugradio.pico.capture_data('50mV', divisor=8, dual_mode=True)
np.savetxt('data_2.6.2_lower', x)

# first lo set to 1229 MHz -- lower baseband

# %%
x = np.loadtxt('data_2.6.2_lower')
a = x[:len(x)/2]
b = x[len(x)/2:]
c = a + b * 1j
PS(c)
# Out:
# <img src="data:image/png;base64,...">
